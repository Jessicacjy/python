# %% [markdown]
# ## matplotlib
#
# * library for making 2D plots of arrays in Python.
# * written primarily in pure Python
# * makes heavy use of NumPy and other extension code to provide good performance even for large arrays.
# * create simple plots with just a few commands

# %%
# %pylab inline
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ### Basic plotting

# %%
x = np.linspace (0 , 10 , 20)
y = np.cos(x)
plt.plot(x,y)
plt.show()
#help(np.linspace)

# %% [markdown]
# ## Basic plotting - Colours, markers, line styles
# * colours: r, g, b, c, m, y, k, w
# * markers: . , o v ^ < > * + x and more
# * line style: - -- -. :
# * line width (lw) and marker size (ms) as keyword arguments

# %%
x = np.linspace (0 , 10 , 20)
y = np.sin(x)
plt.plot(x, y, 'g+--',
         x, np.cos(x) , 'm>-',
         lw =10 , ms =5)
plt.show ()

# %% [markdown]
# ## Scatter plots with scatter

# %%
#help(np.random.normal)
#help(plt.scatter)
z=np.random.normal (5,2,(2,100)) #Unpack
x,y = z
print(x)
print(y)
# Out:
# [  3.70674961   2.44002335   2.9094045    7.27672342   7.08709846
#    7.17124968   7.68191555   2.47044196   7.68540051   5.33947904
#    2.0987376    2.87292929   1.7764929    6.39136473   7.89132573
#    2.47126917   9.0006438    3.23010867   5.33030279   1.54470056
#    6.85726232   4.90362679   5.22396037   8.55161948   4.53163473
#    1.22450128   3.89888102   3.53887741   2.49943868   3.84991779
#    4.30078202   2.13242906   7.443679     5.09886003   5.7305926
#    3.07996848   3.9471776    7.72147063   4.67785363   6.22725369
#    3.65684188   5.71186005   6.92425389   6.79391542   6.46515729
#    7.55248825   4.70992829   4.69739313   2.11772908   4.48737578
#    4.70166791   6.13194736   5.70098456   5.65107685   5.43066945
#    5.0209189    6.87892155   4.17962119   2.99019599   8.03890134
#    5.38663303   6.68913694   4.24593642   3.34747662   5.26508742
#    6.9131214    8.71579915   4.86548189   7.29636794   5.49880337
#    4.66414702   4.52251983  10.37898335   4.77734922   3.169775
#    5.49088437   7.9645956    3.87795296   3.74232174   2.56341945
#    3.23751036   3.61562132   3.62376671   6.37335535   4.48256468
#    6.4994803    6.73793807   3.45977825   3.1861014    4.5967327
#    4.71833616   4.36386265   3.82949666   5.27394345   7.28622948
#    4.24814117   5.001807     8.943624     3.87372668   3.90829598]
# [  4.79139447   8.51643089   8.30945642   6.42736523   7.36158633
#    7.54355776   4.11863276   2.83535873   3.62523053   4.88465038
#    2.51708682   0.6995553    8.94272771   4.01809014   6.0598321
#    3.48306657   4.25562215   6.66104017   7.92024309   5.80322818
#    7.74306396   3.94258748   5.66486104   4.10937456   6.86374503
#    4.08651968   7.71159179   2.87580901   6.92721458   6.21753816
#    9.08714136   7.12254114   6.83798911   5.33147111   3.68919365
#    5.56264598   7.299789     6.96049553   4.65653524   1.58195761
#    6.61596767   3.10264843   4.75348016   4.89591806   3.14873564
#    3.05205663   4.16244145   3.13249642   4.82394233   6.88756258
#    5.52489677   2.99414686   2.35232162   2.28897356   7.33037059
#    2.31173075   4.71435057   1.50288581   4.29223925   1.46906327
#    7.15797006   1.1878653    1.69259332   6.75556889   7.97488354
#    4.73655361   6.04161713   1.79740517   7.8796317    4.50275938
#    4.31971462   2.33884447   0.75153323   7.67715325   6.41911094
#    4.1639133    4.54940582   7.06679027  -0.18950462   6.47526927
#    2.00762812   5.0489172    2.63990841   4.75024206   7.10492377
#    2.35846691   9.60149166   2.62448215   7.08415423   5.42523341
#    6.09669077  10.03410252   7.2665295    3.54663858   2.88469327
#    6.4219657    5.42698928   5.09088592   5.70917002   4.53360975]

# %%
# c is color
# s is marker size
x,y=np.random.normal (5,2,(2,100))
plt.scatter (x,y,c=x+y, s=10*x - 10 * y)
plt.show()

#print(x)
# Out:
# C:\Anaconda3\lib\site-packages\matplotlib\collections.py:806: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %% [markdown]
# ## Histograms

# %%
x,y=np.random.triangular (5 ,7 ,10 ,(2 ,1000))
plt.hist (x, 50 , normed =1 , facecolor ='r')
plt.show ()

# %% [markdown]
# ## Contour lines

# %%
xx = yy = np.linspace(-5,5)
#xx ,yy = np.meshgrid(xx,yy)
zz = np.fromfunction(
                    lambda i,j: np.cos(xx[i]**2+yy[j]**2)*np.exp(-(xx[i]**2+ yy[j]**2)/10),
                    (50 ,50) , dtype =int)
plt.contourf (xx ,yy ,zz)
plt.show ()

# %% [markdown]
# ### Samples
#
# http://matplotlib.org/gallery.html
